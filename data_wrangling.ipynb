# %%
import configparser
from datetime import datetime
import os
from pyspark.sql import SparkSession, SQLContext
from pyspark.sql.functions import udf, col, to_timestamp, monotonically_increasing_id
from pyspark.sql.functions import year, month, dayofmonth, hour, weekofyear, date_format
import pandas as pd

# %%
config = configparser.ConfigParser()
config.read('dl.cfg')

os.environ['AWS_ACCESS_KEY_ID']=config['AWS']['AWS_ACCESS_KEY_ID']
os.environ['AWS_SECRET_ACCESS_KEY']=config['AWS']['AWS_SECRET_ACCESS_KEY']

# %%
spark = SparkSession \
    .builder \
    .config("spark.jars.packages", "org.apache.hadoop:hadoop-aws:2.7.0") \
    .getOrCreate()

# %%
df = spark\
    .read.option("header", "true")\
    .option("inferSchema", "true")\
    .option("charset", "UTF-8")\
    .json('s3a://udacity-dend/song_data/*/*/*/*.json')

# %%
df.printSchema()
# Out:
# root
#  |-- artist_id: string (nullable = true)
#  |-- artist_latitude: double (nullable = true)
#  |-- artist_location: string (nullable = true)
#  |-- artist_longitude: double (nullable = true)
#  |-- artist_name: string (nullable = true)
#  |-- duration: double (nullable = true)
#  |-- num_songs: long (nullable = true)
#  |-- song_id: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- year: long (nullable = true)

# %%
df.limit(5).toPandas()
# Out:
#             artist_id  artist_latitude  \
# 0  AR4T2IF1187B9ADBB7         63.96027
# 1  AR4T2IF1187B9ADBB7         63.96027
# 2  ARQ846I1187B9A7083              NaN
# 3  AR4T2IF1187B9ADBB7         63.96027
# 4  AR3TZ691187FB3DBB1              NaN
#
#                                      artist_location  artist_longitude  \
# 0  <a href="http://billyidol.net" onmousedown='Un...          10.22442
# 1  <a href="http://billyidol.net" onmousedown='Un...          10.22442
# 2                                                                  NaN
# 3  <a href="http://billyidol.net" onmousedown='Un...          10.22442
# 4                                                                  NaN
#
#                                          artist_name   duration  num_songs  \
# 0                                         Billy Idol  233.22077          1
# 1                                         Billy Idol  287.92118          1
# 2  Yvonne S. Moriarty / Walt Fowler / Ladd McInto...  196.04853          1
# 3                                         Billy Idol  247.53587          1
# 4  Russell Watson / Pino Palladino / Robbie McInt...  273.44934          1
#
#               song_id                                              title  year
# 0  SOVIYJY12AF72A4B00       The Dead Next Door (Digitally Remastered 99)  1983
# 1  SOVYXYL12AF72A3373                 Rebel Yell (1999 Digital Remaster)  1983
# 2  SOEPTVC12A67ADD0DA  To Zucchabar ["Gladiator" - Music from the Mot...     0
# 3  SOLQYSZ12AB0181F97                                   Mony Mony (Live)  1987
# 4  SOVPFJK12A6701CB16                Barcelona - (Friends until the end)  2000

# %%
songs_table = df.select('song_id', 'title', 'artist_id', 'year', 'duration')

# %%
songs_table.limit(10).toPandas()
# Out:
#               song_id           artist_id  year   duration
# 0  SOVIYJY12AF72A4B00  AR4T2IF1187B9ADBB7  1983  233.22077
# 1  SOVYXYL12AF72A3373  AR4T2IF1187B9ADBB7  1983  287.92118
# 2  SOEPTVC12A67ADD0DA  ARQ846I1187B9A7083     0  196.04853
# 3  SOLQYSZ12AB0181F97  AR4T2IF1187B9ADBB7  1987  247.53587
# 4  SOVPFJK12A6701CB16  AR3TZ691187FB3DBB1  2000  273.44934
# 5  SOETDBF12A81C20BC0  AR4T2IF1187B9ADBB7  2005  237.06077
# 6  SOIEXLS12A6D4F792F  AR4T2IF1187B9ADBB7  1993  443.14077
# 7  SOQEBML12A8C136AA4  AR5R7791187FB3A8C3     0   55.40526
# 8  SOTCIHX12A8C13DDD2  ARYOIZG1187FB41E30  2006  483.34322
# 9  SODUMDU12AC468A22B  ARHOSMU1242078130D     0  249.54730

# %% [markdown]
# ### Log data
#
# read loga data with inferSchema option

# %%
log_data = spark \
        .read \
        .option("header", "true") \
        .option("inferSchema", "true") \
        .option("charset", "UTF-8") \
        .json('s3a://udacity-dend/log-data/*/*/*.json')

# %%
# display structure
log_data.printSchema()
# Out:
# root
#  |-- artist: string (nullable = true)
#  |-- auth: string (nullable = true)
#  |-- firstName: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- itemInSession: long (nullable = true)
#  |-- lastName: string (nullable = true)
#  |-- length: double (nullable = true)
#  |-- level: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- method: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- registration: double (nullable = true)
#  |-- sessionId: long (nullable = true)
#  |-- song: string (nullable = true)
#  |-- status: long (nullable = true)
#  |-- ts: long (nullable = true)
#  |-- userAgent: string (nullable = true)
#  |-- userId: string (nullable = true)

# %%
# filter by 'NextSong' event and pring out first 10 records with Pandas

log_data = log_data.filter(col('page')== 'NextSong')
log_data.filter(col('page')== 'NextSong').limit(5).toPandas()
# Out:
#         artist       auth firstName gender  itemInSession  lastName  \
# 0     Harmonia  Logged In      Ryan      M              0     Smith
# 1  The Prodigy  Logged In      Ryan      M              1     Smith
# 2        Train  Logged In      Ryan      M              2     Smith
# 3  Sony Wonder  Logged In    Samuel      M              0  Gonzalez
# 4    Van Halen  Logged In     Tegan      F              2    Levine
#
#       length level                              location method      page  \
# 0  655.77751  free    San Jose-Sunnyvale-Santa Clara, CA    PUT  NextSong
# 1  260.07465  free    San Jose-Sunnyvale-Santa Clara, CA    PUT  NextSong
# 2  205.45261  free    San Jose-Sunnyvale-Santa Clara, CA    PUT  NextSong
# 3  218.06975  free  Houston-The Woodlands-Sugar Land, TX    PUT  NextSong
# 4  289.38404  paid           Portland-South Portland, ME    PUT  NextSong
#
#    registration  sessionId                                            song  \
# 0  1.541017e+12        583                                   Sehr kosmisch
# 1  1.541017e+12        583                                 The Big Gundown
# 2  1.541017e+12        583                                        Marry Me
# 3  1.540493e+12        597                                       Blackbird
# 4  1.540794e+12        602  Best Of Both Worlds (Remastered Album Version)
#
#    status             ts                                          userAgent  \
# 0     200  1542241826796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 1     200  1542242481796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 2     200  1542242741796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 3     200  1542253449796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 4     200  1542260935796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
#
#   userId
# 0     26
# 1     26
# 2     26
# 3     61
# 4     80

# %% [markdown]
# ### Creat user table
#
# Extract data from log file timestamp and create **user_table** with following fields:
#
# - userId
# - firstName
# - lastName
# - gender
# - level

# %%
users_table = log_data.select('userId','firstName', 'lastName', 'gender', 'level')
users_table.show(5)
# Out:
# +------+---------+--------+------+-----+
# |userId|firstName|lastName|gender|level|
# +------+---------+--------+------+-----+
# |    26|     Ryan|   Smith|     M| free|
# |    26|     Ryan|   Smith|     M| free|
# |    26|     Ryan|   Smith|     M| free|
# |     9|    Wyatt|   Scott|     M| free|
# |    12|   Austin| Rosales|     M| free|
# +------+---------+--------+------+-----+
# only showing top 5 rows

# %% [markdown]
# ### Creat time table
#
# Extract data from log file timestamp and create **time_table** with following fields:
#
# - ts
# - datetime
# - hour
# - day
# - week
# - month
# - year

# %%
# Extract ts column to the new dataframe
df_time = log_data.select('ts')

# add 'datetime' column with date in "yyyy-MM-dd hh:mm:ss" format 
df_time = df_time.withColumn('datetime', to_timestamp((df_time['ts']/1000) \
                 .cast('timestamp'), "yyyy-MM-dd hh:mm:ss"))

# %%
df_time.show(5)
# Out:
# +-------------+-------------------+
# |           ts|           datetime|
# +-------------+-------------------+
# |1542241826796|2018-11-14 16:30:26|
# |1542242481796|2018-11-14 16:41:21|
# |1542242741796|2018-11-14 16:45:41|
# |1542253449796|2018-11-14 19:44:09|
# |1542260935796|2018-11-14 21:48:55|
# +-------------+-------------------+
# only showing top 5 rows

# %%
# extract hour, day, week, month, yeat from datetime and add to the dataframe 
time_table = df_time.withColumn('hour', hour(col('datetime'))) \
                        .withColumn('day', dayofmonth(col('datetime'))) \
                        .withColumn('week', weekofyear(col('datetime'))) \
                        .withColumn('month', month(col('datetime'))) \
                        .withColumn('year', year(col('datetime')))

# %%
time_table.show(5)
# Out:
# +-------------+-------------------+----+---+----+-----+----+
# |           ts|           datetime|hour|day|week|month|year|
# +-------------+-------------------+----+---+----+-----+----+
# |1542241826796|2018-11-14 16:30:26|  16| 14|  46|   11|2018|
# |1542242481796|2018-11-14 16:41:21|  16| 14|  46|   11|2018|
# |1542242741796|2018-11-14 16:45:41|  16| 14|  46|   11|2018|
# |1542253449796|2018-11-14 19:44:09|  19| 14|  46|   11|2018|
# |1542260935796|2018-11-14 21:48:55|  21| 14|  46|   11|2018|
# +-------------+-------------------+----+---+----+-----+----+
# only showing top 5 rows

# %% [markdown]
# ### Creat songplay table
#
# Extract data from both song-data and log-data and create **songplays_table**  with following fields:
#
# - songplayId
# - start_time
# - userId
# - level
# - songId
# - artistId
# - sessionId
# - location
# - userAgent
# - month
# - year

# %%
songplays_table = df.join(log_data, (df.artist_name == log_data.artist) &  (df.title == log_data.song)) \
                             .withColumn('songplay_id', monotonically_increasing_id()) \
                             .withColumn('start_time', to_timestamp((log_data['ts']/1000) \
                                                       .cast('timestamp'), 'yyyy-MM-dd hh:mm:ss')) \
                             .select('songplay_id', \
                                     'start_time', \
                                     'userId', \
                                     'level', \
                                     'song', \
                                     'sessionId', \
                                     'artist_location', \
                                     'userAgent', \
                                     month(col('start_time')).alias('month'), \
                                     year(col('start_time')).alias('year'))

# %%
songplays_table.limit(5).toPandas()
# Out:
#    songplay_id          start_time userId level  \
# 0   8589934592 2018-11-21 00:25:43     88  paid
# 1  25769803776 2018-11-29 08:58:01     49  paid
# 2  34359738368 2018-11-28 00:18:57     58  paid
# 3  34359738369 2018-11-28 15:34:43     24  paid
# 4  68719476736 2018-11-26 07:37:14     88  paid
#
#                                                 song  sessionId  \
# 0  Die Kunst der Fuge_ BWV 1080 (2007 Digital Rem...        744
# 1  Fighters (feat. Matthew Santos) (Amended Album...       1041
# 2  Suena ("Some Day" end title song "The Hunchbac...        887
# 3  It's Not Easy (Being Green) (Featuring Pierre ...        984
# 4  Shimmy Shimmy Quarter Turn (Take It Back To Sq...        900
#
#          artist_location                                          userAgent  \
# 0    Geneva, Switzerland  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 1            Chicago, IL  Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# 2  San Juan, Puerto Rico  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# 3   Berkeley, California  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 4   Huntington Beach, CA  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
#
#    month  year
# 0     11  2018
# 1     11  2018
# 2     11  2018
# 3     11  2018
# 4     11  2018

# %%
# print out how data looks
songplays_table.limit(10).toPandas()
# Out:
#     songplay_id          start_time userId level  \
# 0    8589934592 2018-11-21 00:25:43     88  paid
# 1   25769803776 2018-11-29 08:58:01     49  paid
# 2   34359738368 2018-11-28 00:18:57     58  paid
# 3   34359738369 2018-11-28 15:34:43     24  paid
# 4   68719476736 2018-11-26 07:37:14     88  paid
# 5  103079215104 2018-11-16 09:18:51     36  paid
# 6  103079215105 2018-11-29 20:57:03     49  paid
# 7  111669149696 2018-11-28 13:05:13     73  paid
# 8  111669149697 2018-11-27 10:22:58     36  paid
# 9  137438953472 2018-11-03 10:59:01     15  paid
#
#                                                 song  sessionId  \
# 0  Die Kunst der Fuge_ BWV 1080 (2007 Digital Rem...        744
# 1  Fighters (feat. Matthew Santos) (Amended Album...       1041
# 2  Suena ("Some Day" end title song "The Hunchbac...        887
# 3  It's Not Easy (Being Green) (Featuring Pierre ...        984
# 4  Shimmy Shimmy Quarter Turn (Take It Back To Sq...        900
# 5  Waterfall (Spirit Of The Rainforest Album Vers...        461
# 6  Waterfall (Spirit Of The Rainforest Album Vers...       1079
# 7                         Where The Wild Things Were        954
# 8                                          Let It Go        957
# 9  Catch You Baby (Steve Pitron & Max Sanna Radio...        199
#
#              artist_location  \
# 0        Geneva, Switzerland
# 1                Chicago, IL
# 2      San Juan, Puerto Rico
# 3       Berkeley, California
# 4       Huntington Beach, CA
# 5                  Tennessee
# 6                  Tennessee
# 7  UK - England - South East
# 8                Oakland, CA
# 9                     Nevada
#
#                                            userAgent  month  year
# 0  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     11  2018
# 1  Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...     11  2018
# 2  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...     11  2018
# 3  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...     11  2018
# 4  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     11  2018
# 5  "Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537....     11  2018
# 6  Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...     11  2018
# 7  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     11  2018
# 8  "Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537....     11  2018
# 9  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     11  2018
